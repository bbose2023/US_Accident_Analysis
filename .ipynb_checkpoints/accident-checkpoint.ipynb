# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import chardet as chardet
import dask as dask
import dask.dataframe as dd

import sys
import subprocess
from pathlib import Path

# Import Dependencies
import psycopg2
from pymongo import MongoClient
from pprint import pprint
from utils import createCSV, createCSVUsingDask

# %%
def createUSAccidentData(base_path):
    createCSV(f"{base_path}/accident_2022.csv",f"{base_path}/label_name_file.csv","us_accident","w")
    createCSV(f"{base_path}/accident_2021.csv",f"{base_path}/label_name_file.csv","us_accident","a")
    createCSV(f"{base_path}/accident_2020.csv",f"{base_path}/label_name_file.csv","us_accident","a")
    createCSV(f"{base_path}/accident_2019.csv",f"{base_path}/label_name_file.csv","us_accident","a")

# %%
import import_ipynb as ipynb
def loadUSAccidentDataToMongoDB():
    object_names = ['us_accident']
    # Pass the collection names
    from mongodb_load_databases import createMongoDB, validateMongoDB
    db_name = 'us_accidents_db'
    createMongoDB(db_name, object_names)
    validateMongoDB(db_name)

# %%
import import_ipynb as ipynb
def loadUSAccidentDataToMongoDBCluster():
    object_names = ['us_accident']
    # Pass the collection names
    from mongodb_load_databases import createMongoDBCluster, validateMongoDBCluster
    db_name = 'us_accidents_db'
    createMongoDBCluster(db_name, object_names)
    validateMongoDBCluster(db_name)

# %%
base_path = Path("Resources/accident_data")
createUSAccidentData(base_path)
loadUSAccidentDataToMongoDB()
# Out:
# Starting to read the File
# ################Labels to Save###################### Index(['STATENAME', 'ST_CASE', 'VE_TOTAL', 'PVH_INVL', 'PEDS', 'PERSONS',
#        'PERMVIT', 'PERNOTMVIT', 'COUNTYNAME', 'CITYNAME', 'DAY', 'MONTHNAME',
#        'YEAR', 'DAY_WEEKNAME', 'HOURNAME', 'MINUTE', 'NHSNAME', 'ROUTENAME',
#        'TWAY_ID', 'RUR_URBNAME', 'FUNC_SYSNAME', 'RD_OWNERNAME', 'LATITUDE',
#        'LONGITUD', 'SP_JURNAME', 'HARM_EVNAME', 'RELJCT1NAME', 'WRK_ZONENAME',
#        'REL_ROADNAME', 'LGT_CONDNAME', 'FATALS'],
#       dtype='object')
# ################Updated CSV File#################       STATENAME  ST_CASE  PEDS  PERNOTMVIT  VE_TOTAL  PVH_INVL  PERSONS  \
# 0       Alabama    10001     0           0         2         0        3
# 1       Alabama    10002     0           0         2         0        5
# 2       Alabama    10003     0           0         1         0        2
# 3       Alabama    10004     0           0         1         0        1
# 4       Alabama    10005     1           1         1         0        1
# ...         ...      ...   ...         ...       ...       ...      ...
# 39216   Wyoming   560114     0           0         2         0        2
# 39217   Wyoming   560115     0           0         1         0        1
# 39218   Wyoming   560116     0           0         1         0        1
# 39219   Wyoming   560117     0           0         1         0        1
# 39220   Wyoming   560118     0           0         1         0        4
#
#        PERMVIT        COUNTYNAME        CITYNAME  ...  \
# 0            3     PICKENS (107)  NOT APPLICABLE  ...
# 1            5  MONTGOMERY (101)  NOT APPLICABLE  ...
# 2            2   ST. CLAIR (115)  NOT APPLICABLE  ...
# 3            1  MONTGOMERY (101)  NOT APPLICABLE  ...
# 4            1    JEFFERSON (73)  NOT APPLICABLE  ...
# ...        ...               ...             ...  ...
# 39216        2   SWEETWATER (37)    ROCK SPRINGS  ...
# 39217        1      LINCOLN (23)  NOT APPLICABLE  ...
# 39218        1      LARAMIE (21)        CHEYENNE  ...
# 39219        1      JOHNSON (19)  NOT APPLICABLE  ...
# 39220        4      LARAMIE (21)  NOT APPLICABLE  ...
#
#                               NHSNAME               SP_JURNAME   LATITUDE  \
# 0          This section IS ON the NHS  No Special Jurisdiction  33.490967
# 1          This section IS ON the NHS  No Special Jurisdiction  32.087125
# 2      This section IS NOT on the NHS  No Special Jurisdiction  33.428331
# 3          This section IS ON the NHS  No Special Jurisdiction  32.216903
# 4          This section IS ON the NHS  No Special Jurisdiction  33.540281
# ...                               ...                      ...        ...
# 39216      This section IS ON the NHS  No Special Jurisdiction  41.586956
# 39217  This section IS NOT on the NHS                    Other  42.398061
# 39218  This section IS NOT on the NHS  No Special Jurisdiction  41.144981
# 39219  This section IS NOT on the NHS  No Special Jurisdiction  44.328569
# 39220  This section IS NOT on the NHS  No Special Jurisdiction  41.041992
#
#          LONGITUD                 HARM_EVNAME  RELJCT1NAME REL_ROADNAME  \
# 0      -88.274083  Motor Vehicle In-Transport           No   On Roadway
# 1      -86.064153  Motor Vehicle In-Transport           No   On Roadway
# 2      -86.351994        Tree (Standing Only)           No  On Roadside
# 3      -86.400169                       Ditch           No  On Roadside
# 4      -86.687389                  Pedestrian           No  On Shoulder
# ...           ...                         ...          ...          ...
# 39216 -109.248764  Motor Vehicle In-Transport           No   On Roadway
# 39217 -110.909786           Rollover/Overturn           No   On Roadway
# 39218 -104.824736                        Curb           No  On Roadside
# 39219 -106.812689                     Boulder           No  On Roadside
# 39220 -104.121756           Rollover/Overturn           No  On Roadside
#
#       WRK_ZONENAME        LGT_CONDNAME FATALS
# 0              NaN            Daylight      1
# 1              NaN            Daylight      2
# 2              NaN  Dark - Not Lighted      1
# 3              NaN            Daylight      1
# 4              NaN  Dark - Not Lighted      1
# ...            ...                 ...    ...
# 39216          NaN            Daylight      1
# 39217          NaN                Dawn      1
# 39218          NaN            Daylight      1
# 39219          NaN  Dark - Not Lighted      1
# 39220          NaN  Dark - Not Lighted      1
#
# [39221 rows x 31 columns]
# Starting to read the File
# ################Labels to Save###################### Index(['STATENAME', 'ST_CASE', 'VE_TOTAL', 'PVH_INVL', 'PEDS', 'PERSONS',
#        'PERMVIT', 'PERNOTMVIT', 'COUNTYNAME', 'CITYNAME', 'DAY', 'MONTHNAME',
#        'YEAR', 'DAY_WEEKNAME', 'HOURNAME', 'MINUTE', 'NHSNAME', 'ROUTENAME',
#        'TWAY_ID', 'RUR_URBNAME', 'FUNC_SYSNAME', 'RD_OWNERNAME', 'LATITUDE',
#        'LONGITUD', 'SP_JURNAME', 'HARM_EVNAME', 'RELJCT1NAME', 'WRK_ZONENAME',
#        'REL_ROADNAME', 'LGT_CONDNAME', 'FATALS'],
#       dtype='object')
# ################Updated CSV File#################       STATENAME  ST_CASE  PEDS  PERNOTMVIT  VE_TOTAL  PVH_INVL  PERSONS  \
# 0       Alabama    10001     0           0         2         0        3
# 1       Alabama    10002     0           0         1         0        2
# 2       Alabama    10003     1           1         1         0        1
# 3       Alabama    10004     0           0         1         0        1
# 4       Alabama    10005     0           0         2         0        4
# ...         ...      ...   ...         ...       ...       ...      ...
# 39780   Wyoming   560100     0           0         1         0        2
# 39781   Wyoming   560101     0           0         2         0        2
# 39782   Wyoming   560102     0           0         1         0        1
# 39783   Wyoming   560103     1           1         1         0        1
# 39784   Wyoming   560104     0           0         2         0        2
#
#        PERMVIT       COUNTYNAME        CITYNAME  ...  \
# 0            3  ST. CLAIR (115)  NOT APPLICABLE  ...
# 1            2   JEFFERSON (73)  NOT APPLICABLE  ...
# 2            1   JEFFERSON (73)  NOT APPLICABLE  ...
# 3            1     SHELBY (117)  NOT APPLICABLE  ...
# 4            4   JEFFERSON (73)  NOT APPLICABLE  ...
# ...        ...              ...             ...  ...
# 39780        2     JOHNSON (19)  NOT APPLICABLE  ...
# 39781        2     BIG HORN (3)  NOT APPLICABLE  ...
# 39782        1  SWEETWATER (37)  NOT APPLICABLE  ...
# 39783        1     LARAMIE (21)        CHEYENNE  ...
# 39784        2     LINCOLN (23)  NOT APPLICABLE  ...
#
#                               NHSNAME               SP_JURNAME   LATITUDE  \
# 0          This section IS ON the NHS  No Special Jurisdiction  33.601642
# 1          This section IS ON the NHS  No Special Jurisdiction  33.541361
# 2          This section IS ON the NHS  No Special Jurisdiction  33.419797
# 3          This section IS ON the NHS  No Special Jurisdiction  33.360894
# 4          This section IS ON the NHS  No Special Jurisdiction  33.815208
# ...                               ...                      ...        ...
# 39780  This section IS NOT on the NHS  No Special Jurisdiction  44.183594
# 39781  This section IS NOT on the NHS  No Special Jurisdiction  44.257797
# 39782      This section IS ON the NHS  No Special Jurisdiction  41.560719
# 39783      This section IS ON the NHS  No Special Jurisdiction  41.138878
# 39784      This section IS ON the NHS  No Special Jurisdiction  42.997253
#
#          LONGITUD                 HARM_EVNAME  RELJCT1NAME REL_ROADNAME  \
# 0      -86.312383  Motor Vehicle In-Transport           No   On Roadway
# 1      -86.643744    Concrete Traffic Barrier           No    On Median
# 2      -86.752572                  Pedestrian           No  On Shoulder
# 3      -86.777139                       Ditch           No  On Roadside
# 4      -86.825342  Motor Vehicle In-Transport           No   On Roadway
# ...           ...                         ...          ...          ...
# 39780 -106.622031           Rollover/Overturn           No  On Roadside
# 39781 -107.856219  Motor Vehicle In-Transport           No   On Roadway
# 39782 -109.536278           Rollover/Overturn           No  On Roadside
# 39783 -104.766653                  Pedestrian           No   On Roadway
# 39784 -111.012300  Motor Vehicle In-Transport           No   On Roadway
#
#       WRK_ZONENAME        LGT_CONDNAME FATALS
# 0              NaN  Dark - Not Lighted      2
# 1              NaN  Dark - Not Lighted      2
# 2              NaN  Dark - Not Lighted      1
# 3              NaN            Daylight      1
# 4              NaN  Dark - Not Lighted      1
# ...            ...                 ...    ...
# 39780          NaN            Daylight      1
# 39781          NaN  Dark - Not Lighted      1
# 39782          NaN            Daylight      1
# 39783          NaN  Dark - Not Lighted      1
# 39784          NaN  Dark - Not Lighted      1
#
# [39785 rows x 31 columns]
# Starting to read the File
# ################Labels to Save###################### Index(['STATENAME', 'ST_CASE', 'VE_TOTAL', 'PVH_INVL', 'PEDS', 'PERSONS',
#        'PERMVIT', 'PERNOTMVIT', 'COUNTYNAME', 'CITYNAME', 'DAY', 'MONTHNAME',
#        'YEAR', 'DAY_WEEKNAME', 'HOURNAME', 'MINUTE', 'NHSNAME', 'ROUTENAME',
#        'TWAY_ID', 'RUR_URBNAME', 'FUNC_SYSNAME', 'RD_OWNERNAME', 'LATITUDE',
#        'LONGITUD', 'SP_JURNAME', 'HARM_EVNAME', 'RELJCT1NAME', 'WRK_ZONENAME',
#        'REL_ROADNAME', 'LGT_CONDNAME', 'FATALS'],
#       dtype='object')
# ################Updated CSV File#################       STATENAME  ST_CASE  VE_TOTAL  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0       Alabama    10001         1         0     0           0        4
# 1       Alabama    10002         4         0     0           0        6
# 2       Alabama    10003         2         0     0           0        2
# 3       Alabama    10004         1         0     0           0        5
# 4       Alabama    10005         1         0     0           0        1
# ...         ...      ...       ...       ...   ...         ...      ...
# 35930   Wyoming   560111         2         0     0           0        2
# 35931   Wyoming   560112         3         0     0           0        8
# 35932   Wyoming   560113         3         0     0           0        9
# 35933   Wyoming   560114         2         0     1           1        3
# 35934   Wyoming   560115         1         0     0           0        2
#
#        PERSONS      COUNTYNAME        CITYNAME  ...  \
# 0            4     ELMORE (51)  NOT APPLICABLE  ...
# 1            6  JEFFERSON (73)      BIRMINGHAM  ...
# 2            2    SHELBY (117)  NOT APPLICABLE  ...
# 3            5    CALHOUN (15)  NOT APPLICABLE  ...
# 4            1      COOSA (37)  NOT APPLICABLE  ...
# ...        ...             ...             ...  ...
# 35930        2    LARAMIE (21)  NOT APPLICABLE  ...
# 35931        8    LINCOLN (23)  NOT APPLICABLE  ...
# 35932        9    FREMONT (13)  NOT APPLICABLE  ...
# 35933        3    LARAMIE (21)        CHEYENNE  ...
# 35934        2     PLATTE (31)  NOT APPLICABLE  ...
#
#                            RD_OWNERNAME   LATITUDE    LONGITUD  \
# 0                 County Highway Agency  32.433133  -86.094850
# 1      City or Municipal Highway Agency  33.484658  -86.839544
# 2                  State Highway Agency  33.299942  -86.369642
# 3                 County Highway Agency  33.795072  -85.883486
# 4                 County Highway Agency  32.848414  -86.083547
# ...                                 ...        ...         ...
# 35930             County Highway Agency  41.211981 -105.123781
# 35931              State Highway Agency  42.814131 -110.957272
# 35932              State Highway Agency  42.993033 -108.406514
# 35933              State Highway Agency  41.138478 -104.787133
# 35934              State Highway Agency  41.663031 -104.839778
#
#                     SP_JURNAME                 HARM_EVNAME  RELJCT1NAME  \
# 0      No Special Jurisdiction        Tree (Standing Only)           No
# 1      No Special Jurisdiction  Motor Vehicle In-Transport           No
# 2      No Special Jurisdiction                       Ditch           No
# 3      No Special Jurisdiction        Tree (Standing Only)           No
# 4      No Special Jurisdiction        Tree (Standing Only)           No
# ...                        ...                         ...          ...
# 35930  No Special Jurisdiction  Motor Vehicle In-Transport           No
# 35931  No Special Jurisdiction  Motor Vehicle In-Transport           No
# 35932       Indian Reservation  Motor Vehicle In-Transport           No
# 35933  No Special Jurisdiction  Motor Vehicle In-Transport           No
# 35934  No Special Jurisdiction           Rollover/Overturn           No
#
#       WRK_ZONENAME REL_ROADNAME        LGT_CONDNAME FATALS
# 0              NaN  On Roadside  Dark - Not Lighted      3
# 1              NaN   On Roadway      Dark - Lighted      1
# 2              NaN  On Roadside            Daylight      1
# 3              NaN  On Roadside            Daylight      1
# 4              NaN  On Roadside  Dark - Not Lighted      1
# ...            ...          ...                 ...    ...
# 35930          NaN   On Roadway  Dark - Not Lighted      1
# 35931          NaN   On Roadway  Dark - Not Lighted      2
# 35932          NaN   On Roadway  Dark - Not Lighted      1
# 35933          NaN   On Roadway  Dark - Not Lighted      1
# 35934          NaN   On Roadway            Daylight      1
#
# [35935 rows x 31 columns]
# Starting to read the File
# ################Labels to Save###################### Index(['STATENAME', 'ST_CASE', 'VE_TOTAL', 'PVH_INVL', 'PEDS', 'PERSONS',
#        'PERMVIT', 'PERNOTMVIT', 'COUNTYNAME', 'CITYNAME', 'DAY', 'MONTHNAME',
#        'YEAR', 'DAY_WEEKNAME', 'HOURNAME', 'MINUTE', 'NHSNAME', 'ROUTENAME',
#        'TWAY_ID', 'RUR_URBNAME', 'FUNC_SYSNAME', 'RD_OWNERNAME', 'LATITUDE',
#        'LONGITUD', 'SP_JURNAME', 'HARM_EVNAME', 'RELJCT1NAME', 'WRK_ZONENAME',
#        'REL_ROADNAME', 'LGT_CONDNAME', 'FATALS'],
#       dtype='object')
# ################Updated CSV File#################       STATENAME  ST_CASE  VE_TOTAL  PVH_INVL  PEDS  PERSONS  PERMVIT  \
# 0       Alabama    10001         2         0     0        3        3
# 1       Alabama    10002         2         0     0        2        2
# 2       Alabama    10003         3         0     0        4        4
# 3       Alabama    10004         1         0     1        1        1
# 4       Alabama    10005         1         0     0        1        1
# ...         ...      ...       ...       ...   ...      ...      ...
# 33482   Wyoming   560117         1         0     0        1        1
# 33483   Wyoming   560118         5         0     0        6        6
# 33484   Wyoming   560119         1         0     0        1        1
# 33485   Wyoming   560120         1         0     0        2        2
# 33486   Wyoming   560121         2         0     0        3        3
#
#        PERNOTMVIT       COUNTYNAME        CITYNAME  ...          RD_OWNERNAME  \
# 0               0         LEE (81)         OPELIKA  ...  State Highway Agency
# 1               0      ETOWAH (55)         GADSDEN  ...  State Highway Agency
# 2               0    CLEBURNE (29)  NOT APPLICABLE  ...  State Highway Agency
# 3               1      ETOWAH (55)    RAINBOW CITY  ...  State Highway Agency
# 4               0      BALDWIN (3)  NOT APPLICABLE  ...  State Highway Agency
# ...           ...              ...             ...  ...                   ...
# 33482           0       CROOK (11)           Other  ...          Not Reported
# 33483           0       ALBANY (1)  NOT APPLICABLE  ...  State Highway Agency
# 33484           0    SHERIDAN (33)  NOT APPLICABLE  ...  State Highway Agency
# 33485           0     LARAMIE (21)  NOT APPLICABLE  ...  State Highway Agency
# 33486           0  SWEETWATER (37)     GREEN RIVER  ...  State Highway Agency
#
#         LATITUDE    LONGITUD               SP_JURNAME  \
# 0      32.666222  -85.336658  No Special Jurisdiction
# 1      33.997828  -86.053997  No Special Jurisdiction
# 2      33.660842  -85.391011  No Special Jurisdiction
# 3      33.956472  -86.140522  No Special Jurisdiction
# 4      30.656269  -87.809461  No Special Jurisdiction
# ...          ...         ...                      ...
# 33482  44.354406 -104.810853  No Special Jurisdiction
# 33483  41.167136 -105.887706  No Special Jurisdiction
# 33484  44.912142 -107.104503  No Special Jurisdiction
# 33485  41.403750 -104.456917  No Special Jurisdiction
# 33486  41.522656 -109.447392  No Special Jurisdiction
#
#                       HARM_EVNAME  RELJCT1NAME             WRK_ZONENAME  \
# 0      Motor Vehicle In-Transport           No                      NaN
# 1      Motor Vehicle In-Transport           No                      NaN
# 2      Motor Vehicle In-Transport           No                      NaN
# 3                      Pedestrian           No                      NaN
# 4               Rollover/Overturn           No                      NaN
# ...                           ...          ...                      ...
# 33482           Rollover/Overturn           No                      NaN
# 33483  Motor Vehicle In-Transport           No                      NaN
# 33484           Rollover/Overturn           No                      NaN
# 33485                  Embankment           No  Work Zone, Type Unknown
# 33486  Motor Vehicle In-Transport          Yes                      NaN
#
#       REL_ROADNAME        LGT_CONDNAME FATALS
# 0       On Roadway            Daylight      1
# 1       On Roadway  Dark - Not Lighted      1
# 2       On Roadway  Dark - Not Lighted      1
# 3       On Roadway  Dark - Not Lighted      1
# 4      On Roadside  Dark - Not Lighted      1
# ...            ...                 ...    ...
# 33482   On Roadway                Dusk      1
# 33483   On Roadway            Daylight      1
# 33484  On Roadside            Daylight      1
# 33485    On Median  Dark - Not Lighted      1
# 33486   On Roadway  Dark - Not Lighted      2
#
# [33487 rows x 31 columns]
# importing Jupyter notebook from mongodb_load_databases.ipynb
# Imported Resources/us_accident.csv into collection us_accident.
# ['admin', 'config', 'local', 'us_accidents_db']
# ['us_accident']
# us_accident 148431

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# confirm that the "autosaurus" database is in MongoDB
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'us_accidents_db']

# %%
# assign the database to a variable name
db = mongo['us_accidents_db']
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['us_accident']

# %%
# assign each collection to a variable
accident = db['us_accident']

# %%
accident.count_documents({})
query = {
         'YEAR': 2020
        }
# Print the number of results
print("Number of states in result:", accident.count_documents(query))
# Out:
# Number of states in result: 35935
